# %% [markdown]
# # Example prediction on a single test image
#
# This notebook gives example code to make a single disparity prediction for one test image.
#
# The file `test_simple.py` shows a more complete version of this code, which additionally:
# - Can run on GPU or CPU (this notebook only runs on CPU)
# - Can predict for a whole folder of images, not just a single image
# - Saves predictions to `.npy` files and disparity images.

# %%
from __future__ import absolute_import, division, print_function
# %matplotlib inline

import os
import numpy as np
import PIL.Image as pil
import matplotlib.pyplot as plt

import torch
from torchvision import transforms

import networks
from utils import download_model_if_doesnt_exist
from networks import EncodingModule

# %% [markdown]
# ## Setting up network and loading weights

# %%
model_name = "mono_640x192"

download_model_if_doesnt_exist(model_name)
encoder_path = os.path.join("models", model_name, "encoder.pth")
depth_decoder_path = os.path.join("models", model_name, "depth.pth")

# LOADING PRETRAINED MODEL
encoder = networks.ResnetEncoder(18, False)
depth_decoder = networks.DepthDecoder(num_ch_enc=encoder.num_ch_enc, scales=range(4))

loaded_dict_enc = torch.load(encoder_path, map_location='cpu')
filtered_dict_enc = {k: v for k, v in loaded_dict_enc.items() if k in encoder.state_dict()}
encoder.load_state_dict(filtered_dict_enc)

loaded_dict = torch.load(depth_decoder_path, map_location='cpu')
depth_decoder.load_state_dict(loaded_dict)

encoder.eval()
depth_decoder.eval();

# %%
encoder = networks.EncodingModule(18, True, encoder_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-7567f07dc3cd> in <module>
# ----> 1 encoder = networks.EncodingModule(18, True)
#
# ~/mohan/uw_madison/cs838/cs838_project/monodepth2/networks/resnet_encoder.py in __init__(self, num_layers, pretrained, num_input_images)
#     106         self.image_encoder =  ResnetEncoder(
#     107             num_layers, False)
# --> 108         loaded_dict_enc = torch.load('../models/mono_640x192/encoder.pth', map_location='cpu')
#     109         filtered_dict_enc = {k: v for k, v in loaded_dict_enc.items() if k in self.image_encoder.state_dict()}
#     110         self.image_encoder.load_state_dict(filtered_dict_enc)
#
# ~/anaconda3/lib/python3.7/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     379             (sys.version_info[0] == 2 and isinstance(f, unicode)):
#     380         new_fd = True
# --> 381         f = open(f, 'rb')
#     382     elif (sys.version_info[0] == 3 and isinstance(f, pathlib.Path)):
#     383         new_fd = True
#
# FileNotFoundError: [Errno 2] No such file or directory: '../models/mono_640x192/encoder.pth'

# %% [markdown]
# ## Loading the test image and preprocessing

# %%
# image_path = "assets/006656.png"
image_path = "../data_sample/000039.png"
input_image = pil.open(image_path).convert('RGB')
original_width, original_height = input_image.size

feed_height = loaded_dict_enc['height']
feed_width = loaded_dict_enc['width']
input_image_resized = input_image.resize((feed_width, feed_height), pil.LANCZOS)

input_image_pytorch = transforms.ToTensor()(input_image_resized).unsqueeze(0)

# %% [markdown]
# ## Prediction using the PyTorch model

# %%
with torch.no_grad():
    features = encoder(input_image_pytorch)
    outputs = depth_decoder(features)

disp = outputs[("disp", 0)]

# %% [markdown]
# ## Plotting

# %%
disp_resized = torch.nn.functional.interpolate(disp,
    (original_height, original_width), mode="bilinear", align_corners=False)
print(disp_resized.size())
print(disp.size())
print(input_image.size)
# Saving colormapped depth image
disp_resized_np = disp_resized.squeeze().cpu().numpy()
vmax = np.percentile(disp_resized_np, 95)

plt.figure(figsize=(10, 10))
plt.subplot(211)
plt.imshow(input_image)
plt.title("Input", fontsize=22)
plt.axis('off')

plt.subplot(212)
plt.imshow(disp_resized_np, cmap='cividis', vmax=vmax)
plt.title("Depth prediction", fontsize=22)
plt.axis('off');
# Out:
# torch.Size([1, 1, 375, 1242])
# torch.Size([1, 1, 192, 640])
# (1242, 375)

# %% [markdown]
# ## Projections

# %%
def lidar_to_camera(x, y, z):
    MATRIX_T_VELO_2_CAM = np.array ([
        [7.49916597e-03, -9.99971248e-01, -8.65110297e-04, -6.71807577e-03],
        [1.18652889e-02, 9.54520517e-04, -9.99910318e-01, -7.33152811e-02],
        [9.99882833e-01, 7.49141178e-03, 1.18719929e-02, -2.78557062e-01],
        [0, 0, 0, 1]
    ])
    
    MATRIX_R_RECT_0 = np.array(([
        [0.99992475, 0.00975976, -0.00734152, 0],
        [-0.0097913, 0.99994262, -0.00430371, 0],
        [0.00729911, 0.0043753, 0.99996319, 0],
        [0, 0, 0, 1]
    ]))
    
    P_MAT =  ([[719.787081,    0.,            608.463003, 44.9538775],
                      [0.,            719.787081,    174.545111, 0.1066855],
                      [0.,            0.,            1.,         3.0106472e-03],
                      [0.,            0.,            0.,         0]])
    
    p = np.array([x, y, z, 1])
    p = np.matmul(MATRIX_T_VELO_2_CAM, p)
    p = np.matmul(MATRIX_R_RECT_0, p)
    p = np.matmul(P_MAT, p)
    p = p[0:3]
    return p


def kitti_lidar_to_camera(points):
    if points.shape[1] == 4:
        points = points[:, 0:3]
    num_points = points.shape[0]
    camera_points = np.zeros((num_points, 3))
    image_points = np.zeros((num_points, 3))
    for i in range(num_points):
        p = points[i, :]
        p = lidar_to_camera(p[0], p[1], p[2])
        camera_points[i, :] = p
        image_points[i,:] = p / p[2]
        
    return camera_points, image_points
        

def kitti_camera_to_lidar(disparity_map):
    MATRIX_P2 = np.array([[719.787081,    0.,            608.463003, 44.9538775],
                          [0.,            719.787081,    174.545111, 0.1066855],
                          [0.,            0.,            1.,         3.0106472e-03],
                          [0.,            0.,            0.,         0]])
    #print(MATRIX_P2.shape)
    int_mat = MATRIX_P2[0:3,0:3]
    #print(int_mat)
    #print(disp_resized_np.shape)
    points = []
    for i in range(disp_resized_np.shape[0]):
        for j in range(disp_resized_np.shape[1]):
            pt = disp_resized_np[i,j]*np.dot(np.linalg.inv(int_mat), np.array([i,j,1]))
            points.append(pt)
    
    return np.array(points)

# %%
import numpy as np
import scipy.io as sio
from math import floor

image_path = "../data_sample/000039.png"
lidar_path = "../data_sample/000039_pc_crop.mat"

image_path2 = "../data_sample/006656/006656.png"
lidar_path2 = "../data_sample/006656/lidar_cropped.mat"

input_image = np.array(pil.open(image_path2).convert('RGB'))

pc = sio.loadmat(lidar_path2)['val']
cpoints, ipoints = kitti_lidar_to_camera(pc)

# %%
print(cpoints.shape)
# for cpoint in cpoints:
#     print(cpoint)
print(np.max(ipoints[:, 0]))
print(np.max(ipoints[:, 1]))
print(np.max(ipoints[:, 2]))
print(np.min(ipoints[:, 0]))
print(np.min(ipoints[:, 1]))
print(np.min(ipoints[:, 2]))

print(input_image.shape)

output = np.zeros(tuple(input_image.shape))

for i in range(ipoints.shape[0]):
    y = floor(ipoints[i, 1])
    x = floor(ipoints[i, 0])
    if x < output.shape[1] and y < output.shape[0]:
        output[y, x, :] = floor(cpoints[i, 2])

plt.figure(figsize=(30, 30))    
plt.imshow(output)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (16709, 3)
# 1240.3491963408894
# 375.3729181459853
# 1.0
# -2.5984819401981345
# 119.95280708940801
# 1.0
# (370, 1224, 3)

# %%
print(np.max(cpoints[:,2]))
print(np.min(cpoints[:,2]))
# Out:
# 53.45050490426961
# 5.502838585927604

# %%
# input_image = np.random(())
MATRIX_P2 = np.array([[719.787081,    0.,            608.463003, 44.9538775],
                      [0.,            719.787081,    174.545111, 0.1066855],
                      [0.,            0.,            1.,         3.0106472e-03],
                      [0.,            0.,            0.,         0]])
print(MATRIX_P2.shape)
int_mat = MATRIX_P2[0:3,0:3]
print(int_mat)
print(disp_resized_np.shape)
points = []
for i in range(disp_resized_np.shape[0]):
    for j in range(disp_resized_np.shape[1]):
        pt = disp_resized_np[i,j]*np.dot(np.linalg.inv(int_mat), np.array([i,j,1]))
        points.append(pt)
# Out:
# (4, 4)
# [[719.787081   0.       608.463003]
#  [  0.       719.787081 174.545111]
#  [  0.         0.         1.      ]]
# (375, 1242)

# %%
P = np.array(points)
P.shape
# Out:
# (465750, 3)

# %%
import scipy.io as sio
P = np.array(points)
sio.savemat('../data_sample/000039_depth.mat',{'points':P})

# %%
import pptk
P = np.array(points)
print(P.shape)
v = pptk.viewer(P) 
v.set(point_size=0.01)
# Out:
# (452880, 3)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-48d1eb6c4721> in <module>
#       2 P = np.array(points)
#       3 print(P.shape)
# ----> 4 v = pptk.viewer(P)
#       5 v.set(point_size=0.01)
#
# ~/anaconda3/lib/python3.7/site-packages/pptk/viewer/viewer.py in __init__(self, *args, **kwargs)
#      55             print ('Started viewer process: %s' \
#      56                 % os.path.join(_viewer_dir, 'viewer'))
# ---> 57         x = s.accept()
#      58         self._portNumber = struct.unpack('H', self._process.stdout.read(2))[0]
#      59         # self._portNumber = struct.unpack('H',x[0].recv(2))[0]
#
# ~/anaconda3/lib/python3.7/socket.py in accept(self)
#     210         For IP sockets, the address info is a pair (hostaddr, port).
#     211         """
# --> 212         fd, addr = self._accept()
#     213         sock = socket(self.family, self.type, self.proto, fileno=fd)
#     214         # Issue #7995: if no default timeout is set and the listening
#
# KeyboardInterrupt:
